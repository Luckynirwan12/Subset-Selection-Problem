# %% [markdown]
# <a href="https://colab.research.google.com/github/Luckynirwan12/Subset-Selection-Problem/blob/main/Subset_Selection_Problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **1. Problem Statement:**
# -> Find all the subsets from a set of numbers whose sum is zero.
#
# -> Constraint: Subset size must be 5.
#
# -> Set={-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4}

# %%
# This will import combinations() from itertools
from itertools import combinations

# Given Set
A = set([12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, 4])

# Size of the Subset
subset_size = 5

# It will store the subset with size 5 and sum 0
result_list = []

# Loop to find subset with size 5 and sum 0
for subset in combinations(A, subset_size):
  if sum(subset) == 0:
    result_list.append(subset)

# Print total number of subset
print("Total number of subset : ",len(result_list))

# Print all possible subset
for i, subset in enumerate(result_list, 1):  # enumerate() add index from result_list by 1
  print(f"{i}. {subset}")
# Out:
# Total number of subset :  123
# 1. (1, 2, 4, -5, -2)
# 2. (1, 2, 6, -7, -2)
# 3. (1, 2, 6, -6, -3)
# 4. (1, 2, 7, -8, -2)
# 5. (1, 2, 7, -7, -3)
# 6. (1, 2, 9, -9, -3)
# 7. (1, 2, 9, -7, -5)
# 8. (1, 2, 11, -9, -5)
# 9. (1, 2, 11, -8, -6)
# 10. (1, 2, 12, -9, -6)
# 11. (1, 2, 12, -8, -7)
# 12. (1, 3, 4, -6, -2)
# 13. (1, 3, 4, -5, -3)
# 14. (1, 3, 6, -8, -2)
# 15. (1, 3, 6, -7, -3)
# 16. (1, 3, 7, -9, -2)
# 17. (1, 3, 7, -8, -3)
# 18. (1, 3, 7, -6, -5)
# 19. (1, 3, 9, -8, -5)
# 20. (1, 3, 9, -7, -6)
# 21. (1, 3, 11, -9, -6)
# 22. (1, 3, 11, -8, -7)
# 23. (1, 3, 12, -9, -7)
# 24. (1, 4, 6, -9, -2)
# 25. (1, 4, 6, -8, -3)
# 26. (1, 4, 6, -6, -5)
# 27. (1, 4, 7, -9, -3)
# 28. (1, 4, 7, -7, -5)
# 29. (1, 4, 9, -9, -5)
# 30. (1, 4, 9, -8, -6)
# 31. (1, 4, 11, -9, -7)
# 32. (1, 4, 12, -9, -8)
# 33. (1, 6, 7, -9, -5)
# 34. (1, 6, 7, -8, -6)
# 35. (1, 6, 9, -9, -7)
# 36. (1, 7, 9, -9, -8)
# 37. (1, 9, -5, -3, -2)
# 38. (1, 11, -7, -3, -2)
# 39. (1, 12, -8, -3, -2)
# 40. (1, 12, -6, -5, -2)
# ...

# %% [markdown]
# ### **2. Problem Statement:**
# -> Find all the subsets from a set of numbers whose sum is zero.
#
# -> Constraint: Subset size must be 3 to 6 only
#
# -> Set={-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4}

# %%
# This will import combinations() from itertools
from itertools import combinations

# Given set
A = set([12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, 4])

# Size of the Subset
subset_sizes = [3, 6]

# It will store the subset with size 3 to 6 and sum 0
result_list = []

# Loop to find subset with size 3 to 6 and sum 0
for size in subset_sizes:
    for subset in combinations(A, size):
        if sum(subset) == 0:
            result_list.append(subset)

# Print total number of subset
print("Total zero-sum subsets (sizes 3 to 6):", len(result_list))

# Print all possible subset
for i, subset in enumerate(result_list, 1):
    print(f"{i}. {subset}")
# Out:
# Total zero-sum subsets (sizes 3 to 6): 233
# 1. (1, 2, -3)
# 2. (1, 4, -5)
# 3. (1, 6, -7)
# 4. (1, 7, -8)
# 5. (2, 3, -5)
# 6. (2, 4, -6)
# 7. (2, 6, -8)
# 8. (2, 7, -9)
# 9. (3, 4, -7)
# 10. (3, 6, -9)
# 11. (7, -5, -2)
# 12. (9, -7, -2)
# 13. (9, -6, -3)
# 14. (11, -9, -2)
# 15. (11, -8, -3)
# 16. (11, -6, -5)
# 17. (12, -9, -3)
# 18. (12, -7, -5)
# 19. (1, 2, 3, 4, -8, -2)
# 20. (1, 2, 3, 4, -7, -3)
# 21. (1, 2, 3, 6, -9, -3)
# 22. (1, 2, 3, 6, -7, -5)
# 23. (1, 2, 3, 7, -8, -5)
# 24. (1, 2, 3, 7, -7, -6)
# 25. (1, 2, 3, 9, -9, -6)
# 26. (1, 2, 3, 9, -8, -7)
# 27. (1, 2, 3, 11, -9, -8)
# 28. (1, 2, 4, 6, -8, -5)
# 29. (1, 2, 4, 6, -7, -6)
# 30. (1, 2, 4, 7, -9, -5)
# 31. (1, 2, 4, 7, -8, -6)
# 32. (1, 2, 4, 9, -9, -7)
# 33. (1, 2, 6, 7, -9, -7)
# 34. (1, 2, 7, -5, -3, -2)
# 35. (1, 2, 9, -7, -3, -2)
# 36. (1, 2, 11, -9, -3, -2)
# 37. (1, 2, 11, -7, -5, -2)
# 38. (1, 2, 11, -6, -5, -3)
# 39. (1, 2, 12, -8, -5, -2)
# 40. (1, 2, 12, -7, -6, -2)
# 41. (1, 2, 12, -7, -5, -3)
# ...
